# %% [markdown]
# # Required Installation of Packages

# %%
# !pip install noisereduce librosa soundfile
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from noisereduce) (3.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->noisereduce) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.12.14)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->noisereduce) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->noisereduce) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->noisereduce) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->noisereduce) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->noisereduce) (2024.2.0)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3

# %% [markdown]
# ---

# %% [markdown]
# # Functions to Save and Read Data in JSON Format Using Python

# %%
import json

# %%
def save_to_json(data, file_path):
    """
    Save data to a JSON file.
    
    Args:
    - data: Python object (e.g., dict or list) to save.
    - file_path: Path to the JSON file.
    """
    try:
        with open(file_path, "w") as json_file:
            json.dump(data, json_file, indent=4)  # Save with pretty formatting
        print(f"Data successfully saved to {file_path}")
    except Exception as e:
        print(f"Error saving data to JSON: {e}")

# %%
def read_from_json(file_path):
    """
    Read data from a JSON file.
    
    Args:
    - file_path: Path to the JSON file.
    
    Returns:
    - The Python object (e.g., dict or list) loaded from the JSON file.
    """
    try:
        with open(file_path, "r") as json_file:
            data = json.load(json_file)
        print(f"Data successfully loaded from {file_path}")
        return data
    except Exception as e:
        print(f"Error reading data from JSON: {e}")
        return None

# %% [markdown]
# ---

# %% [markdown]
# # Necessary Installations

# %%
# Install pyOpenSMILE for feature extraction
# !pip install opensmile
# Out:
# Collecting opensmile
#   Downloading opensmile-2.5.1-py3-none-manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting audobject>=0.6.1 (from opensmile)
#   Downloading audobject-0.7.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting audinterface>=0.7.0 (from opensmile)
#   Downloading audinterface-1.3.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting audeer>=2.1.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audeer-2.2.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting audformat<2.0.0,>=1.0.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audformat-1.3.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting audiofile>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audiofile-1.5.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting audmath>=1.4.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audmath-1.4.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting audresample<2.0.0,>=1.1.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audresample-1.3.4-py3-none-manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: asttokens>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from audobject>=0.6.1->opensmile) (3.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from audobject>=0.6.1->opensmile) (8.5.0)
# Collecting oyaml (from audobject>=0.6.1->opensmile)
#   Downloading oyaml-1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from audobject>=0.6.1->opensmile) (24.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from audeer>=2.1.1->audinterface>=0.7.0->opensmile) (4.67.1)
# Collecting iso639-lang (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso639_lang-2.6.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting iso3166 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.2.2)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (17.0.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.4.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2024.2.0)
# Downloading opensmile-2.5.1-py3-none-manylinux_2_17_x86_64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.0/996.0 kB 25.3 MB/s eta 0:00:00
# Downloading audinterface-1.3.1-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 4.4 MB/s eta 0:00:00
# Downloading audobject-0.7.12-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.1 MB/s eta 0:00:00
# Downloading audeer-2.2.2-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.9 MB/s eta 0:00:00
# Downloading audformat-1.3.2-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 3.6 MB/s eta 0:00:00
# Downloading audiofile-1.5.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.5 MB/s eta 0:00:00
# Downloading audmath-1.4.2-py3-none-any.whl (23 kB)
# Downloading audresample-1.3.4-py3-none-manylinux_2_17_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.4/138.4 kB 7.0 MB/s eta 0:00:00
# Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Downloading iso639_lang-2.6.0-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 17.8 MB/s eta 0:00:00
# Installing collected packages: oyaml, iso639-lang, iso3166, audeer, audobject, audmath, audiofile, audresample, audformat, audinterface, opensmile
# Successfully installed audeer-2.2.2 audformat-1.3.2 audinterface-1.3.1 audiofile-1.5.1 audmath-1.4.2 audobject-0.7.12 audresample-1.3.4 iso3166-2.1.1 iso639-lang-2.6.0 opensmile-2.5.1 oyaml-1.0

# %% [markdown]
# ---

# %% [markdown]
# # Extracting Audio Features

# %%
import opensmile
import os
import torch
import librosa
import noisereduce as nr
import numpy as np
import soundfile as sf
import tempfile
import json

# %%
def preprocess_audio(audio_path):
    """
    Apply noise reduction and amplitude normalization to audio
    while preserving the original sample rate (44kHz)
    
    Returns path to temporary processed audio file
    """
    try:
        # Load audio at original 44kHz sample rate
        y, sr = librosa.load(audio_path, sr=44100, mono=True)
        
        # 1. Noise reduction
        reduced_noise = nr.reduce_noise(
            y=y, 
            sr=sr,
            stationary=True,
            prop_decrease=0.75
        )
        
        # 2. Amplitude normalization (peak to -3dB)
        max_amplitude = np.max(np.abs(reduced_noise))
        if max_amplitude > 0:
            scaling_factor = 10 ** (-3 / 20) / max_amplitude
            normalized_audio = reduced_noise * scaling_factor
        else:
            normalized_audio = reduced_noise  # Avoid division by zero
        
        # Create temporary file for processed audio
        temp_file = tempfile.NamedTemporaryFile(suffix=".wav", delete=False)
        temp_path = temp_file.name
        temp_file.close()
        
        # Save processed audio with original sample rate
        sf.write(temp_path, normalized_audio, sr, subtype='PCM_16')
        
        return temp_path
        
    except Exception as e:
        print(f"Error preprocessing audio {audio_path}: {e}")
        return None

# %%
def extract_audio_features(audio_path, device='cpu'):
    """
    Extract audio features using OpenSMILE with preprocessing and return them as a list.

    Args:
    - audio_path: Path to the input audio file (.wav or .mp4).
    - device: Placeholder for future GPU support (OpenSMILE is CPU-only).

    Returns:
    - features_list: List containing the extracted features.
    """
    try:
        # Preprocess audio (returns path to temp file)
        processed_path = preprocess_audio(audio_path)

        if not processed_path:
            return None
            
        # Initialize OpenSMILE with the eGeMAPS configuration
        smile = opensmile.Smile(
            feature_set=opensmile.FeatureSet.ComParE_2016,  # Use ComParE_2016 feature set
            feature_level=opensmile.FeatureLevel.Functionals  # Functionals for aggregated features
        )

        # Extract features from processed audio
        features_df = smile.process_file(processed_path)
        
        # Clean up temporary file
        if os.path.exists(processed_path):
            os.remove(processed_path)

        # Convert DataFrame to list
        features_list = features_df.values.flatten().tolist()
        
        # Placeholder for GPU conversion if using other methods
        if device == 'cuda':
            print("Note: OpenSMILE runs on CPU. GPU not utilized for feature extraction.")
        
        return features_list

    except Exception as e:
        # Clean up if error occurs
        if processed_path and os.path.exists(processed_path):
            os.remove(processed_path)
            
        print(f"Error extracting features from {audio_path}: {e}")
        return None

# %%
def process_audio_data(audio_data, device='cpu'):
    """
    Process the nested audio data structure to extract features using OpenSMILE.

    Args:
    - audio_data: Dictionary containing train/dev/test splits with audio file paths.
    - device: Specify 'cpu' or 'cuda' (GPU). OpenSMILE uses CPU regardless.

    Returns:
    - audio_features_opensmile: Dictionary with extracted features in the desired format.
    """
    # Initialize split_features dynamically based on input data
    split_features = {split: [] for split in audio_data.keys()}

    for split, items in audio_data.items():
        for item in items:
            for key, audio_path in item.items():
                if key not in ["y", "label"]:
                    print(f"Processing {audio_path} (using {device.upper()})...")
                    features_list = extract_audio_features(audio_path, device=device)

                    if features_list is not None:
                        temp_dict = {
                            key: audio_path,
                            f"{key}_opensmile_features": features_list,
                            "y": item.get("y", None),
                            "label": item.get("label", None)
                        }
                        split_features[split].append(temp_dict)
    
    return split_features

# %% [markdown]
# ---

# %% [markdown]
# # Test code

# %%
if __name__ == "__main__":
    # Example Input
    MELD_audio_data_updated = {
    "train": [
        {
            "0_0": "/kaggle/input/meld-audio/audio_train/dia0_utt0.wav",
            "y": 0,
            "label": "neutral"
        },
        {
            "0_1": "/kaggle/input/meld-audio/audio_train/dia0_utt1.wav",
            "y": 0,
            "label": "neutral"
        },
        {
            "0_2": "/kaggle/input/meld-audio/audio_train/dia0_utt2.wav",
            "y": 0,
            "label": "neutral"
        }
        ],

    "dev": [
        {
            "0_0": "/kaggle/input/meld-audio/audio_dev/dia0_utt0.wav",
            "y": 3,
            "label": "sadness"
        },
        {
            "0_1": "/kaggle/input/meld-audio/audio_dev/dia0_utt1.wav",
            "y": 1,
            "label": "surprise"
        },
        {
            "1_0": "/kaggle/input/meld-audio/audio_dev/dia1_utt0.wav",
            "y": 0,
            "label": "neutral"
        }
        
        ],

    "test": [
        {
            "0_0": "/kaggle/input/meld-audio/audio_test/dia0_utt0.wav",
            "y": 1,
            "label": "surprise"
        },
        {
            "0_1": "/kaggle/input/meld-audio/audio_test/dia0_utt1.wav",
            "y": 6,
            "label": "anger"
        },
        {
            "0_2": "/kaggle/input/meld-audio/audio_test/dia0_utt2.wav",
            "y": 0,
            "label": "neutral"
        }

        ]
    }
    

    # Process Audio Data
    Audio_Features_OpenSMILE = process_audio_data(MELD_audio_data_updated)

    # Print Results
    for split, features in Audio_Features_OpenSMILE.items():
        print(f"\nSplit: {split}")

        # Loop through each entry in the 'train' dataset of MELD_audio_data_updated
        for entry in features:
            identifier = next(iter(entry))
            # Access the 'opensmile_features' list and print its length
            opensmile_features_length = len(entry[f"{identifier}_opensmile_features"])
            print(f"Opensmile Features (length): {opensmile_features_length}")
            print("\n")
# Out:
# Processing /kaggle/input/meld-audio/audio_train/dia0_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_train/dia0_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_train/dia0_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_dev/dia0_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_dev/dia0_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_dev/dia1_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia0_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia0_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia0_utt2.wav (using CPU)...
#
# Split: train
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373
#
#
#
# Split: dev
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373
#
#
#
# Split: test
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373
#
#
# Opensmile Features (length): 6373

# %% [markdown]
# ---

# %% [markdown]
# # Feature Extraction for MELD Audio Data with pyOpenSMILE

# %% [markdown]
# ## Read Updated MELD Audio Data in JSON Format

# %%
# Example Usage
if __name__ == "__main__":
    # Filepath
    MELD_audio_data_updated_file_path = "/kaggle/input/meld-emotion-recognition/JSON files/JSON files/Final Format/MELD_Audio_Data_Updated_Cleaned.json"

    # Read data from JSON
    MELD_audio_data_updated = read_from_json(MELD_audio_data_updated_file_path)
wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia262_utt16.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia263_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia264_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia264_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia264_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia264_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia265_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia265_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt11.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt12.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt13.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt14.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt15.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia266_utt16.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia267_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt11.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt12.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia268_utt13.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia269_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia269_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia269_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia269_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia269_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt11.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt12.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt13.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia270_utt14.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia271_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia272_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia273_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia273_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia273_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia273_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia274_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia274_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia274_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia274_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia274_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia275_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia275_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia275_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia275_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia276_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia277_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt11.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt12.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt13.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt14.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt15.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia278_utt16.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt0.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt1.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt2.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt3.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt4.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt5.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt6.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt7.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt8.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt9.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt10.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt11.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt12.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt13.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt14.wav (using CPU)...
# Processing /kaggle/input/meld-audio/audio_test/dia279_utt15.wav (using CPU)...

# %% [markdown]
# ---

# %% [markdown]
# # Structuring Extracted Audio Features

# %%
# Extracted Features from Audio Using pyOpenSMILE (Audio_Features_OpenSMILE.json)

"""

Audio_Features_OpenSMILE = {
    "train": [
        {
            "0_0": "/kaggle/input/meld-audio/audio_train/dia0_utt0.wav",
            "0_0_OpenSMILE": ,
            "y": 0,
            "label": "neutral"
        },
        {
            "0_1": "/kaggle/input/meld-audio/audio_train/dia0_utt1.wav",
            "0_1_OpenSMILE": ,
            "y": 0,
            "label": "neutral"
        },
        {
            "0_2": "/kaggle/input/meld-audio/audio_train/dia0_utt2.wav",
            "0_2_OpenSMILE": ,
            "y": 0,
            "label": "neutral"
        },

        .................................................. (so on)

        ],

    "dev": [
        {
            "0_0": "/kaggle/input/meld-audio/audio_train/dia0_utt0.wav",
            "0_0_OpenSMILE": ,
            "y": 3,
            "label": "sadness"
        },
        {
            "0_1": "/kaggle/input/meld-audio/audio_train/dia0_utt1.wav",
            "0_1_OpenSMILE": ,
            "y": 1,
            "label": "surprise"
        },
        {
            "1_0": "/kaggle/input/meld-audio/audio_train/dia1_utt0.wav",
            "1_0_OpenSMILE": ,
            "y": 0,
            "label": "neutral"
        },
        
        .................................................. (so on)
        
        ],

    "test": [
        {
            "0_0": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt0.wav",
            "0_0_OpenSMILE": ,
            "y": 1,
            "label": "surprise"
        },
        {
            "0_1": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt1.wav",
            "0_1_OpenSMILE": ,
            "y": 6,
            "label": "anger"
        },
        {
            "0_2": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt2.wav",
            "0_2_OpenSMILE": ,
            "y": 0,
            "label": "neutral"
        },

        .................................................. (so on)

        ]
    }

"""
# Out:
# '\n\nAudio_Features_OpenSMILE = {\n    "train": [\n        {\n            "0_0": "/kaggle/input/meld-audio/audio_train/dia0_utt0.wav",\n            "0_0_OpenSMILE": ,\n            "y": 0,\n            "label": "neutral"\n        },\n        {\n            "0_1": "/kaggle/input/meld-audio/audio_train/dia0_utt1.wav",\n            "0_1_OpenSMILE": ,\n            "y": 0,\n            "label": "neutral"\n        },\n        {\n            "0_2": "/kaggle/input/meld-audio/audio_train/dia0_utt2.wav",\n            "0_2_OpenSMILE": ,\n            "y": 0,\n            "label": "neutral"\n        },\n\n        .................................................. (so on)\n\n        ],\n\n    "dev": [\n        {\n            "0_0": "/kaggle/input/meld-audio/audio_train/dia0_utt0.wav",\n            "0_0_OpenSMILE": ,\n            "y": 3,\n            "label": "sadness"\n        },\n        {\n            "0_1": "/kaggle/input/meld-audio/audio_train/dia0_utt1.wav",\n            "0_1_OpenSMILE": ,\n            "y": 1,\n            "label": "surprise"\n        },\n        {\n            "1_0": "/kaggle/input/meld-audio/audio_train/dia1_utt0.wav",\n            "1_0_OpenSMILE": ,\n            "y": 0,\n            "label": "neutral"\n        },\n        \n        .................................................. (so on)\n        \n        ],\n\n    "test": [\n        {\n            "0_0": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt0.wav",\n            "0_0_OpenSMILE": ,\n            "y": 1,\n            "label": "surprise"\n        },\n        {\n            "0_1": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt1.wav",\n            "0_1_OpenSMILE": ,\n            "y": 6,\n            "label": "anger"\n        },\n        {\n            "0_2": "/kaggle/input/meld-emotion-recognition/MELD.Raw/MELD.Raw/test/output_repeated_splits_test/dia0_utt2.wav",\n            "0_2_OpenSMILE": ,\n            "y": 0,\n            "label": "neutral"\n        },\n\n        .................................................. (so on)\n\n        ]\n    }\n\n'

# %% [markdown]
# ---

# %% [markdown]
# # Save Extracted Audio Features in JSON Format

# %%
# Example Usage
if __name__ == "__main__":
    # Filepath
    Audio_Features_OpenSMILE_file_path = "/kaggle/working/Audio_Features_OpenSMILE.json"

    # Save data to JSON
    save_to_json(Audio_Features_OpenSMILE, Audio_Features_OpenSMILE_file_path)
# Out:
# Data successfully saved to /kaggle/working/Audio_Features_OpenSMILE.json
